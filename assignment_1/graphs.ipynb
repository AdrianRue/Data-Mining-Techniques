# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('dataset_mood_smartphone.csv')
del df['Unnamed: 0']
df[['Date', 'Time']] = df['time'].str.split(' ', n=1, expand=True)

# %%
(df['variable'] == 'sms').head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 df['variable'] == 'sms'.head()
#
# AttributeError: 'str' object has no attribute 'head'

# %%
df['id'].value_counts()
unique_ids = df['id'].unique()

# %%
for person in unique_ids:
    df.loc[(df['id'] == '{}'.format(person)) & (df['variable'] == 'mood')].plot.line(x='time', y='value')
    plt.title('{}'.format(person))
# Out:
# c:\Users\arues\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\core.py:512: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig = self.plt.figure(figsize=self.figsize)

# %%
unique_values = df['variable'].unique()

# %%
for value in unique_values:
    df.loc[(df['id'] == 'AS14.01') & (df['variable'] == '{}'.format(value))].plot.line(x='time', y='value')
    plt.title('{}'.format(value))

plt.show()

# %%
All_IDs = df['id'].unique()

# for value in unique_values:

#     for id in All_IDs:
#         new_df = df.loc[(df['id'] == '{}'.format(id)) & (df['variable'] == '{}'.format(value))]
#         plt.plot(new_df['time'], new_df['value'], label = '{}'.format(id))
#     plt.title('Variable {}'.format(value))
#     plt.show()
        

for id in All_IDs:
    new_df = df.loc[(df['id'] == '{}'.format(id)) & (df['variable'] == 'mood')]
    plt.plot(new_df['time'], new_df['value'], label = '{}'.format(id))
plt.legend()
plt.show()

# %%
df['variable'].value_counts()
# Out:
# screen                  96578
# appCat.builtin          91288
# appCat.communication    74276
# appCat.entertainment    27125
# activity                22965
# appCat.social           19145
# appCat.other             7650
# circumplex.valence       5643
# circumplex.arousal       5643
# appCat.office            5642
# mood                     5641
# call                     5239
# appCat.travel            2846
# appCat.utilities         2487
# sms                      1798
# appCat.finance            939
# appCat.unknown            939
# appCat.game               813
# appCat.weather            255
# Name: variable, dtype: int64

# %%
for person in unique_ids:
    new_df = df.loc[(df['id'] == '{}'.format(id)) & (df['variable'] == 'mood')]
    test = new_df['variable'].value_counts()
    print(test)
# Out:
# mood    192
# Name: variable, dtype: int64
# mood    192
# Name: variable, dtype: int64
# mood    192
# Name: variable, dtype: int64
# mood    192
# Name: variable, dtype: int64
# mood    192
# Name: variable, dtype: int64
# mood    192
# Name: variable, dtype: int64
# mood    192
# Name: variable, dtype: int64
# mood    192
# Name: variable, dtype: int64
# mood    192
# Name: variable, dtype: int64
# mood    192
# Name: variable, dtype: int64
# mood    192
# Name: variable, dtype: int64
# mood    192
# Name: variable, dtype: int64
# mood    192
# Name: variable, dtype: int64
# mood    192
# Name: variable, dtype: int64
# mood    192
# Name: variable, dtype: int64
# mood    192
# Name: variable, dtype: int64
# mood    192
# Name: variable, dtype: int64
# mood    192
# Name: variable, dtype: int64
# mood    192
# Name: variable, dtype: int64
# mood    192
# Name: variable, dtype: int64
# mood    192
# Name: variable, dtype: int64
# mood    192
# Name: variable, dtype: int64
# ...
